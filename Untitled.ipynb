# %%
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv('look.txt', sep=' ')

# %%
data
# Out:
#                                              rs2192160 rs2822441 rs2822475  \
# 1381 21  Adygei Russia-Caucasus EUROPE 955 F         A         C         T
#                                            F         A         T         T
# 1382 21  Adygei Russia-Caucasus EUROPE 956 F         A         T         C
#                                            F         A         T         T
# 1385 21  Adygei Russia-Caucasus EUROPE 959 M         A         T         C
#                                            M         A         C         T
# 1386 21  Adygei Russia-Caucasus EUROPE 960 F         A         T         C
#                                            F         A         T         T
# 1387 21  Adygei Russia-Caucasus EUROPE 962 F         C         T         T
#                                            F         A         C         T
# 1388 21  Adygei Russia-Caucasus EUROPE 963 F         C         T         T
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA, IncrementalPCA
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler as MMS

# %%
pca = PCA(n_components=2)
le = preprocessing.LabelEncoder()
minmax = MMS()

# %%
dataEncoded = data.T.apply(le.fit_transform)

# %%
dataEncoded = dataEncoded.T

# %%
df_scaled = pd.DataFrame(minmax.fit_transform(dataEncoded), columns=dataEncoded.columns, index = dataEncoded.index)

# %%
df = df_scaled.astype(int)

# %%
pcaed = pca.fit_transform(df)

# %%
pcaDF = pd.DataFrame(pcaed, columns=['PCA1', 'PCA2'], index = dataEncoded.index)

# %%
sns.scatterplot(x = 'PCA1', y = 'PCA2', data = pcaDF, c=country)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-4c40f2ea34c0> in <module>
# ----> 1 sns.scatterplot(x = 'PCA1', y = 'PCA2', data = pcaDF, c=country)
#
# NameError: name 'country' is not defined

# %%
arrays = pcaDF.index

# %%
tuples = list(zip(*arrays))

# %%
index = pd.MultiIndex.from_tuples(tuples, names=['index','number','city','country','continent','sex'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-74f60b7500bd> in <module>
# ----> 1 index = pd.MultiIndex.from_tuples(tuples, names=['index','number','city','country','continent','sex'])
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\multi.py in from_tuples(cls, tuples, sortorder, names)
#     400             arrays = lzip(*tuples)
#     401
# --> 402         return MultiIndex.from_arrays(arrays, sortorder=sortorder, names=names)
#     403
#     404     @classmethod
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\multi.py in from_arrays(cls, arrays, sortorder, names)
#     343
#     344         return MultiIndex(levels=levels, codes=codes, sortorder=sortorder,
# --> 345                           names=names, verify_integrity=False)
#     346
#     347     @classmethod
#
# ...

# %%
arrays

# %%
index
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-c17665332d8f> in <module>
# ----> 1 index
#
# NameError: name 'index' is not defined
